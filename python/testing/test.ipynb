# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

# %%
time = np.linspace(0 , 10 , 100)
s = np.sin(2*np.pi*time) +1j*np.linspace(1,1,100) + 1j*np.cos(5*np.pi*time)

# %%
np.arctan2(1 , 0)
# Out:
# 1.5707963267948966

# %%
np.abs(np.fft.fft(time))
plt.plot(np.linspace(0 , 10 , 100) , np.abs(np.fft.fft(s)))
